# %%
import multiprocessing
multiprocessing.set_start_method("fork")

import pandas as pd
import numpy as np
import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt
# %matplotlib inline

from prophet import Prophet

# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport prophet_projpred
# %aimport prophet_projpred.models
# %aimport prophet_projpred.family
# %aimport prophet_projpred.stats
# %aimport prophet_projpred.plots

# %%
df = pd.read_csv('data/ecuador_dataset.csv')
df['date']=pd.to_datetime(df['date'])
df = df.loc[
    df['family'].isin(
        ['BEVERAGES', 'BREAD/BAKERY', 'CLEANING', 'DELI', 'GROCERY I', 'MEATS', 'PERSONAL CARE', 'POULTRY', 'PRODUCE']),
    ['family', 'date', 'unit_sales', 'onpromotion', 'oil_price', 'precipitation', 
     'tavg', 'tmax', 'tmin', 'yellow maize', 'potatoes']
]
df = df.groupby(by='date').agg(
    unit_sales = pd.NamedAgg(column='unit_sales', aggfunc='sum'),
    onpromotion = pd.NamedAgg(column='onpromotion', aggfunc='sum'),
    oil_price = pd.NamedAgg(column='oil_price', aggfunc='first'),
    precipitation = pd.NamedAgg(column='precipitation', aggfunc='first'),
    tmax = pd.NamedAgg(column='tmax', aggfunc='first'),
    tmin = pd.NamedAgg(column='tmin', aggfunc='first'),
    tavg = pd.NamedAgg(column='tavg', aggfunc='first'),
    yellow_maize = pd.NamedAgg(column='yellow maize', aggfunc='first'),
    potatoes = pd.NamedAgg(column='potatoes', aggfunc='first')
)
df = df.rename(columns={'unit_sales': 'y'})
df = df.rename_axis('ds')
df[['y', 'onpromotion']] = np.log(df[['y', 'onpromotion']])

train = df.loc['2015-05-01':'2017-04-30',:].reset_index()
future = df.loc['2015-05-01':'2017-06-30',:].reset_index()

future
# Out:
#             ds          y  onpromotion  oil_price  precipitation       tmax  \
# 0   2015-05-01  12.508238     7.664816      59.10            0.0  20.300000
# 1   2015-05-02  12.606216     6.190315      59.10            0.0  21.000000
# 2   2015-05-03  12.677281     6.180017      59.10           20.1  21.000000
# 3   2015-05-04  12.323003     6.068426      58.92           16.0  19.000000
# 4   2015-05-05  12.197967     6.059123      60.38            8.9  20.100000
# ..         ...        ...          ...        ...            ...        ...
# 783 2017-06-26  12.583300     7.859027      43.24            0.0  18.520000
# 784 2017-06-27  12.430620     8.023880      44.25            0.0  18.466667
# 785 2017-06-28  12.574611     8.740177      44.74            0.0  18.413333
# 786 2017-06-29  12.367607     8.013674      44.88            0.0  18.360000
# 787 2017-06-30  12.681697     8.545392      46.02            0.0  18.306667
#
#          tmin       tavg  yellow_maize  potatoes
# 0    4.066667  13.950000     21.766667  0.295333
# 1    3.700000  13.400000     21.783333  0.295667
# 2    6.000000  11.300000     21.800000  0.296000
# 3    5.300000  12.100000     21.816667  0.296333
# 4    6.800000  11.900000     21.833333  0.296667
# ..        ...        ...           ...       ...
# 783  7.000000  12.920000     17.961667  0.274667
# 784  7.066667  12.933333     17.990000  0.276000
# 785  7.133333  12.946667     18.018333  0.277333
# 786  7.200000  12.960000     18.046667  0.278667
# 787  7.266667  12.973333     18.075000  0.280000
#
# [788 rows x 10 columns]

# %%
holidays = pd.read_csv('data/holidays_events.csv', parse_dates=['date'])
holidays = holidays[holidays['locale_name'].isin(['Quito', 'Ecuador'])]
holidays = holidays.sort_values(by=['description', 'date']).reset_index()
holidays = holidays[['date', 'description']].rename(columns={'date': 'ds', 'description': 'holiday'})
holidays
# Out:
#             ds               holiday
# 0   2013-05-24  Batalla de Pichincha
# 1   2014-05-24  Batalla de Pichincha
# 2   2015-05-24  Batalla de Pichincha
# 3   2016-05-24  Batalla de Pichincha
# 4   2017-05-24  Batalla de Pichincha
# ..         ...                   ...
# 182 2013-04-29         Viernes Santo
# 183 2014-04-18         Viernes Santo
# 184 2015-04-03         Viernes Santo
# 185 2016-03-25         Viernes Santo
# 186 2017-04-14         Viernes Santo
#
# [187 rows x 2 columns]

# %%
m = prophet_projpred.ReferenceModel(changepoint_prior_scale=0.2, holidays=holidays, mcmc_samples=400, uncertainty_samples=800)

# %%
m.add_seasonality(name='yearly', period=365.25, fourier_order=8, prior_scale=10)
m.add_seasonality(name='monthly', period=30.5, fourier_order=8, prior_scale=10)
m.add_seasonality(name='weekly', period=7, fourier_order=5, prior_scale=10)
m.add_regressor('onpromotion')
m.add_regressor('oil_price')
m.add_regressor('precipitation')
m.add_regressor('tavg')
m.add_regressor('tmax')
m.add_regressor('tmin')
m.add_regressor('potatoes')
m.add_regressor('yellow_maize')

# %%
import os
class suppress_stdout_stderr(object):
    '''
    A context manager for doing a "deep suppression" of stdout and stderr in
    Python, i.e. will suppress all print, even if the print originates in a
    compiled C/Fortran sub-function.
       This will not suppress raised exceptions, since exceptions are printed
    to stderr just before a script exits, and after the context manager has
    exited (at least, I think that is why it lets exceptions through).

    '''
    def __init__(self):
        # Open a pair of null files
        self.null_fds = [os.open(os.devnull, os.O_RDWR) for x in range(2)]
        # Save the actual stdout (1) and stderr (2) file descriptors.
        self.save_fds = (os.dup(1), os.dup(2))

    def __enter__(self):
        # Assign the null pointers to stdout and stderr.
        os.dup2(self.null_fds[0], 1)
        os.dup2(self.null_fds[1], 2)

    def __exit__(self, *_):
        # Re-assign the real stdout/stderr back to (1) and (2)
        os.dup2(self.save_fds[0], 1)
        os.dup2(self.save_fds[1], 2)
        # Close the null files
        os.close(self.null_fds[0])
        os.close(self.null_fds[1])

# %%
with suppress_stdout_stderr():
    m.fit(train)
forecast = m.predict(future)

fig1 = m.plot(forecast)
fig2 = m.plot_components(forecast)

# %%
with suppress_stdout_stderr():
    path = m.search(train, future)
# Out:
#         variable         kl
# 0   yellow_maize   0.199679
# 1       potatoes   2.141979
# 2           tmin   8.876829
# 3      oil_price   9.177558
# 4  precipitation  13.975576
# 5    onpromotion  14.876777
# 6           tavg  15.238268
# 7           tmax  15.347490
#         variable        kl
# 0      oil_price  0.073251
# 1       potatoes  0.122756
# 2           tmin  0.157357
# 3  precipitation  0.165540
# 4    onpromotion  0.181846
# 5           tmax  0.234962
# 6           tavg  0.247109
#         variable        kl
# 0       potatoes  0.052645
# 1  precipitation  0.057198
# 2           tmin  0.063938
# 3    onpromotion  0.065627
# 4           tmax  0.070396
# 5           tavg  0.084437
#         variable        kl
# 0  precipitation  0.043750
# 1           tmax  0.050970
# 2    onpromotion  0.052690
# 3           tavg  0.053252
# 4           tmin  0.054097
#       variable        kl
# 0         tavg  0.028325
# 1  onpromotion  0.040363
# 2         tmax  0.041898
# 3         tmin  0.055744
#       variable        kl
# 0         tmin  0.019591
# 1  onpromotion  0.023545
# 2         tmax  0.038349
#       variable        kl
# 0         tmax  0.009841
# 1  onpromotion  0.021405
#       variable        kl
# 0  onpromotion  0.007467

# %%
with suppress_stdout_stderr():
    submodels = m.compute_submodels(path, train, future, ndraws_pred=20, iter=3*1e4)

# %%
prophet_projpred.plot_submodels(m, submodels, future)

# %%
prophet_projpred.plot_submodel_component(m, submodels, future, 'trend')

# %%
prophet_projpred.plot_submodel_component(m, submodels, future, 'trend_extra')

# %%
prophet_projpred.plot_submodel_statistics(submodels)

# %%
for key, value in submodels.items():
    print(value['statistics']['elpd_se'])
# Out:
# 74.29801462914315
# 296.78232302505313
# 256.49280101976666
# 274.22979117521385
# 359.21143246306093
# 274.24843242389494
# 148.04428376025322
# 120.09168234438039
# 385.81388195064176
